# %%
from bs4 import BeautifulSoup
import urllib.request

child0=[]
seed_url = "https://www.federalreserve.gov/newsevents/pressreleases.htm"
maxNum = 10
req = urllib.request.Request(seed_url,headers={'User-Agent': 'Mozilla/5.0'})
webpage = urllib.request.urlopen(req).read()
soup = BeautifulSoup(webpage)
for tag in soup.find_all('a', href = True):
    childUrl = tag['href']
    childUrl = urllib.parse.urljoin(seed_url, childUrl)
    #print(childUrl)
    child0.append(childUrl)
newchild0=[]
newchild2021=[]
for i in child0:
    if "2022" in i:
        newchild0.append(i)
for i in child0:
    if "2021" in i:
        newchild2021.append(i)
child
# Out:
# ['https://www.sec.gov/news/pressreleases#main-content',
#  'https://www.sec.gov/edgar/searchedgar/companysearch',
#  'https://www.sec.gov/',
#  'https://www.sec.gov/',
#  'https://www.sec.gov/about.shtml',
#  'https://www.sec.gov/careers',
#  'https://www.sec.gov/Article/about-commissioners.html',
#  'https://www.sec.gov/contact-information/sec-directory',
#  'https://www.sec.gov/reports',
#  'https://www.sec.gov/answers/about-lawsshtml.html',
#  'https://www.sec.gov/about/what-we-do',
#  'https://www.sec.gov/divisions.shtml',
#  'https://www.sec.gov/divisions/corpfin.shtml',
#  'https://www.sec.gov/divisions/enforce.shtml',
#  'https://www.sec.gov/investment',
#  'https://www.sec.gov/divisions/riskfin.shtml',
#  'https://www.sec.gov/divisions/marketreg.shtml',
#  'https://www.sec.gov/alj',
#  'https://www.sec.gov/exams',
#  'https://www.sec.gov/page/sec-regional-offices',
#  'https://www.sec.gov/divisions.shtml',
#  'https://www.sec.gov/page/litigation',
# ...

# %%
seed_url1 = newchild0[0]
seed_url2=newchild0[1]
seed_url3=newchild2021[0]
seed_url4=newchild2021[1]
child1=[]
child2=[]
child3=[]
child4=[]
req = urllib.request.Request(seed_url1,headers={'User-Agent': 'Mozilla/5.0'})
webpage = urllib.request.urlopen(req).read()
soup = BeautifulSoup(webpage)
for tag in soup.find_all('a', href = True):
    childUrl = tag['href']
    childUrl = urllib.parse.urljoin(seed_url1, childUrl)
    #print(childUrl)
    child1.append(childUrl)
newchild1=[]
for i in child1:
    if "monetary2021" in i:
        newchild1.append(i)

req = urllib.request.Request(seed_url2,headers={'User-Agent': 'Mozilla/5.0'})
webpage = urllib.request.urlopen(req).read()
soup = BeautifulSoup(webpage)
for tag in soup.find_all('a', href = True):
    childUrl = tag['href']
    childUrl = urllib.parse.urljoin(seed_url2, childUrl)
    #print(childUrl)
    child2.append(childUrl)
newchild2=[]
for i in child2:
    if "bcreg2022" in i:
        newchild2.append(i)

req = urllib.request.Request(seed_url3,headers={'User-Agent': 'Mozilla/5.0'})
webpage = urllib.request.urlopen(req).read()
soup = BeautifulSoup(webpage)
for tag in soup.find_all('a', href = True):
    childUrl = tag['href']
    childUrl = urllib.parse.urljoin(seed_url3, childUrl)
    #print(childUrl)
    child3.append(childUrl)
newchild3=[]
for i in child3:
    if "monetary2021" in i:
        newchild3.append(i)

        
req = urllib.request.Request(seed_url4,headers={'User-Agent': 'Mozilla/5.0'})
webpage = urllib.request.urlopen(req).read()
soup = BeautifulSoup(webpage)
for tag in soup.find_all('a', href = True):
    childUrl = tag['href']
    childUrl = urllib.parse.urljoin(seed_url4, childUrl)
    #print(childUrl)
    child4.append(childUrl)
newchild4=[]
for i in child4:
    if "bcreg2021" in i:
        newchild4.append(i)


finalchild=newchild1+newchild2+newchild3+newchild4
finalchild
# Out:
# ['https://www.federalreserve.gov/newsevents/pressreleases/bcreg20221006a.htm',
#  'https://www.federalreserve.gov/newsevents/pressreleases/bcreg20221003a.htm',
#  'https://www.federalreserve.gov/newsevents/pressreleases/bcreg20220930a.htm',
#  'https://www.federalreserve.gov/newsevents/pressreleases/bcreg20220929a.htm',
#  'https://www.federalreserve.gov/newsevents/pressreleases/bcreg20220928a.htm',
#  'https://www.federalreserve.gov/newsevents/pressreleases/bcreg20220927a.htm',
#  'https://www.federalreserve.gov/newsevents/pressreleases/bcreg20220923a.htm',
#  'https://www.federalreserve.gov/newsevents/pressreleases/bcreg20220909a.htm',
#  'https://www.federalreserve.gov/newsevents/pressreleases/bcreg20220816a.htm',
#  'https://www.federalreserve.gov/newsevents/pressreleases/bcreg20220804a.htm',
#  'https://www.federalreserve.gov/newsevents/pressreleases/bcreg20220728a.htm',
#  'https://www.federalreserve.gov/newsevents/pressreleases/bcreg20220719a.htm',
# ...

# %%
count=0
final_url_1=[]
for i in finalchild:
    try:
        req = urllib.request.Request(i,headers={'User-Agent': 'Mozilla/5.0'})
        webpage = urllib.request.urlopen(req).read()
        #opened.append(i)
        soup = BeautifulSoup(webpage)  
        text=soup.get_text().lower()
        if "covid" in text:
            #print(i)
            #print(text)
            final_url_1.append(i)
            count+=1
        if count==10:
            print("haha")
            break
    except Exception as ex:
        continue
# Out:
# woshishabi

# %%
final_url_1#answer of first question
# Out:
# ['https://www.federalreserve.gov/newsevents/pressreleases/bcreg20220214a.htm',
#  'https://www.federalreserve.gov/newsevents/pressreleases/monetary20211215a.htm',
#  'https://www.federalreserve.gov/newsevents/pressreleases/monetary20211103a.htm',
#  'https://www.federalreserve.gov/newsevents/pressreleases/monetary20210922a.htm',
#  'https://www.federalreserve.gov/newsevents/pressreleases/monetary20210616a.htm',
#  'https://www.federalreserve.gov/newsevents/pressreleases/monetary20210428a.htm',
#  'https://www.federalreserve.gov/newsevents/pressreleases/monetary20210317a.htm',
#  'https://www.federalreserve.gov/newsevents/pressreleases/monetary20210127a.htm',
#  'https://www.federalreserve.gov/newsevents/pressreleases/bcreg20210624a.htm',
#  'https://www.federalreserve.gov/newsevents/pressreleases/bcreg20210507a.htm']

# %%
#second question

# %%
child=[]
seed_url = "https://www.sec.gov/news/pressreleases"
maxNum = 10
req = urllib.request.Request(seed_url,headers={'User-Agent': 'Mozilla/5.0'})
webpage = urllib.request.urlopen(req).read()
soup = BeautifulSoup(webpage)
#print(soup.get_text())
for tag in soup.find_all('a', href = True):
    childUrl = tag['href']
    childUrl = urllib.parse.urljoin(seed_url, childUrl)
    print(childUrl)
    child.append(childUrl)
    #soupn=BeautifulSoup(childUrl)
    #print(soupn.find('p').getText())
# Out:
# https://www.sec.gov/news/pressreleases#main-content
# https://www.sec.gov/edgar/searchedgar/companysearch
# https://www.sec.gov/
# https://www.sec.gov/
# https://www.sec.gov/about.shtml
# https://www.sec.gov/careers
# https://www.sec.gov/Article/about-commissioners.html
# https://www.sec.gov/contact-information/sec-directory
# https://www.sec.gov/reports
# https://www.sec.gov/answers/about-lawsshtml.html
# https://www.sec.gov/about/what-we-do
# https://www.sec.gov/divisions.shtml
# https://www.sec.gov/divisions/corpfin.shtml
# https://www.sec.gov/divisions/enforce.shtml
# https://www.sec.gov/investment
# https://www.sec.gov/divisions/riskfin.shtml
# https://www.sec.gov/divisions/marketreg.shtml
# https://www.sec.gov/alj
# https://www.sec.gov/exams
# https://www.sec.gov/page/sec-regional-offices
# https://www.sec.gov/divisions.shtml
# https://www.sec.gov/page/litigation
# https://www.sec.gov/litigation/litreleases.shtml
# https://www.sec.gov/litigation/admin.shtml
# ...

# %%
newchild=[]
for i in child:
    if "2022" in i:
        newchild.append(i)

# %%
newchild
# Out:
# ['https://www.sec.gov/news/press-release/2022-186',
#  'https://www.sec.gov/news/press-release/2022-185',
#  'https://www.sec.gov/news/press-release/2022-184',
#  'https://www.sec.gov/news/press-release/2022-183',
#  'https://www.sec.gov/news/press-release/2022-182',
#  'https://www.sec.gov/news/press-release/2022-181',
#  'https://www.sec.gov/news/press-release/2022-180',
#  'https://www.sec.gov/news/press-release/2022-179',
#  'https://www.sec.gov/news/press-release/2022-178',
#  'https://www.sec.gov/news/press-release/2022-177',
#  'https://www.sec.gov/news/press-release/2022-176',
#  'https://www.sec.gov/news/press-release/2022-175',
#  'https://www.sec.gov/news/press-release/2022-174',
#  'https://www.sec.gov/news/press-release/2022-173',
#  'https://www.sec.gov/news/press-release/2022-172',
#  'https://www.sec.gov/news/press-release/2022-171',
#  'https://www.sec.gov/news/press-release/2022-170',
#  'https://www.sec.gov/news/press-release/2022-169',
# ...

# %%
count=0
final_url=[]
for i in newchild:
    try:
        req = urllib.request.urlopen(i)
        Parse = BeautifulSoup(req, 'html.parser')
        text=Parse.get_text()
        if ("charges" in text) or ("Charges" in text) or ("CHARGES" in text):
            #print(i)
            print(text)
            final_url.append(i)
            count+=1
        if count==20:
            print("haha")
            break
    except Exception as ex:
        continue
# Out:
# SEC.gov | SEC Charges Kim Kardashian for Unlawfully Touting Crypto Security
#
#
#
#
#
#
#
#
#       Skip to main content
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search SEC.gov
#
#
#
# Company Filings
#
#
#
#
#
#
#
#
#
#
#
#
#
# U.S. Securities and Exchange Commission
#
#
# q
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# About
#
#
# Careers
#
#
# Commissioners
#
#
# Contact
#
#
# Reports and Publications
#
#
# Securities Laws
#
#
# What We Do
#
#
#
#
# Divisions & Offices
#
#
# Corporation Finance
#
#
# Enforcement
#
#
# Investment Management
#
#
# Economic and Risk Analysis
#
#
# Trading and Markets
#
#
# Office of Administrative Law Judges
#
#
# Examinations
#
#
# Regional Offices
#
#
# All Divisions and Offices
#
#
#
#
# Enforcement
#
#
# Litigation Releases
#
#
# Administrative Proceedings
#
#
# Opinions and Adjudicatory Orders
#
#
# Accounting and Auditing
#
#
# Trading Suspensions
#
#
# How Investigations Work
#
#
# Receiverships
#
#
# Information for Harmed Investors
#
#
#
#
# Regulation
#
#
# ...

# %%
final_url#answer for q2
# Out:
# ['https://www.sec.gov/news/press-release/2022-183',
#  'https://www.sec.gov/news/press-release/2022-182',
#  'https://www.sec.gov/news/press-release/2022-181',
#  'https://www.sec.gov/news/press-release/2022-180',
#  'https://www.sec.gov/news/press-release/2022-179',
#  'https://www.sec.gov/news/press-release/2022-178',
#  'https://www.sec.gov/news/press-release/2022-176',
#  'https://www.sec.gov/news/press-release/2022-175',
#  'https://www.sec.gov/news/press-release/2022-174',
#  'https://www.sec.gov/news/press-release/2022-173',
#  'https://www.sec.gov/news/press-release/2022-172',
#  'https://www.sec.gov/news/press-release/2022-171',
#  'https://www.sec.gov/news/press-release/2022-170',
#  'https://www.sec.gov/news/press-release/2022-169',
#  'https://www.sec.gov/news/press-release/2022-168',
#  'https://www.sec.gov/news/press-release/2022-167',
#  'https://www.sec.gov/news/press-release/2022-164',
#  'https://www.sec.gov/news/press-release/2022-163',
# ...
